# %% [markdown]
# # 20 Practical Questions on String Methods & Lists with Difficulty
#
# Levels
#
# ## Easy Level (1-7)

# %%
# 1. (Easy) Take a string from user and replace all spaces with underscore _ usingreplace() method.
# 2. (Easy) Take any string and remove leading and trailing spaces using strip().
# 3. (Easy) Take a sentence and check whether it starts with "Hello" using startswith().
# 4. (Easy) Take a string and check if it ends with ".com" using endswith().
# 5. (Easy) Take a comma-separated string like "apple,banana,mango" and split itusing split().
string1 = input("String1:")
print("String replace:",string1.replace(" ","_"))
print("Remove leading and trailing spaces:",string1.strip())
print("Starts with 'Hello':",string1.startswith("Hello"))
print("Ends with '.com':",string1.endswith(".com"))

string2 = input("comma-separated String2:")
print("Spit string2:",string2.split(","))
# Out:
# String1: Hello my mail id is abc@gmail.com
# String replace: Hello_my_mail_id_is_abc@gmail.com
# Remove leading and trailing spaces: Hello my mail id is abc@gmail.com
# Starts with 'Hello': True
# Ends with '.com': True
# comma-separated String2: apple,banana,mango
# Spit string2: ['apple', 'banana', 'mango']

# %%
# 6. (Easy) Create a list of 5 fruits and join them using space " " with join().
list = ["milk","banana","bread","butter"]
list=(" ".join(list))
list
# Out:
# 'milk banana bread butter'

# %%
#7. (Easy) Create a list: [" Python ", " is ", " awesome "]. Strip each word and join
them.
words = ["Python","is","awesome"]
sentence = " ".join(words.strip() for words in words)
print(sentence)
# Out:
# Python is awesome

# %% [markdown]
# ### Medium Level (8-15)

# %%
# 8. (Medium) Take a full name (e.g. "Rahul Kumar Sharma") and print only first and
last name using split().
full_name = input("Full name:")
print("frist and last name:", full_name.split()[0], full_name.split()[2])
# Out:
# Full name: poonam Sunil lonkar
# frist and last name: poonam lonkar

# %%
# 9. (Medium) Take a sentence from user, split it into words, and print the total number of words.
sentence = input("Sentence:")
print("Total number of words:",len(sentence.split()))
# Out:
# Sentence: I just finish my dinner.
# Total number of words: 5

# %%
# 10. (Medium) Take an email address and check if it ends with "@gmail.com" using
endswith().
email =input("Email address:")
email= "Yes"*(email.endswith("@gmail.com")) or "No"
print(email)
# Out:
# Email address: abc@gmail.com
# Yes

# %%
# 11. (Medium) Take a string "Hello World Python" . Replace "World" with "Everyone"
and then split the result.
string = "Hello World Python"
Word= string.replace("World","Everyone")
Word.split()
# Out:
# ['Hello', 'Everyone', 'Python']

# %%
# 12. (Medium) Create a list of 5 city names from user input. Join them with new line"\n" and print.
cities=[]
print("\n".join([input("Enter city name: ") for i in range(5)]))
# Out:
# Enter city name:  Pune
# Enter city name:  Sangali
# Enter city name:  Satar
# Enter city name:  Solapur
# Enter city name:  Mumbai
# Pune
# Sangali
# Satar
# Solapur
# Mumbai

# %%
#13. (Medium) Take a string " hello world ". Strip it, convert to title case, and check if it starts with "Hello".
"Yes" * (" hello world ".strip().title().startswith("Hello")) or "No"
# Out:
# 'Yes'

# %%
#  14. (Medium) Take a sentence and replace the word "bad" with "good" after splitting and joining.
sentence= input("Sentence:")
sentence = sentence.replace("bad","good")
sentence = sentence.split()
print(" ".join(sentence))
# Out:
# Sentence: this is bad.
# this is good.

# %%
# 15. (Medium) Take a list ["10", "20", "30", "40"] and join them with "-" using join().
list= ["10", "20", "30", "40"]
list = ("-".join(list))
list
# Out:
# '10-20-30-40'

# %% [markdown]
# ## Hard Level (16-20)
# * 16. (Hard) Take a sentence. Split into words, remove all words that start with vowel
# (a,e,i,o,u), then join remaining words.
# 17. (Hard) Take a string. Replace all spaces with -, then split by -, and print only
# words with length > 4.
# 18. (Hard) Create a list of student names. Join them with ", ". Then replace the first
# name with "New Student".
# 19. (Hard) Take a paragraph. Split it into sentences (using .), strip each sentence,
# and join them with "\n- ".
# 20. (Hard) Take a string. Use replace(), strip(), split(), and join() together to clean
# and reformat it as a proper sentence.

# %%
# 16. (Hard) Take a sentence. Split into words, remove all words that start with vowel (a,e,i,o,u), then join remaining words.
sentence = input("Sentence:")
words = sentence.split("-")
# Out:
# Sentence: I an good

# %%
# 17. (Hard) Take a string. Replace all spaces with -, then split by -, and print only words with length > 4.
string=input("string:")
string=string.replace(" ","-")
string=string.split("-")
print(len("string > 4"))
# Out:
# string: beautiful
# 10

# %%
# 18. (Hard) Create a list of student names. Join them with ", ". Then replace the first name with "New Student".
student_name_list = ["Poonam","Ishaan","Rahee","Sunil"]
student_name_list = ("-".join(student_name_list ))
student_name_list = student_name_list .replace("Poonam","New Student")
student_name_list
# Out:
# 'New Student-Ishaan-Rahee-Sunil'

# %%
# 19. (Hard) Take a paragraph. Split it into sentences (using .), strip each sentence,and join them with "\n- ".
paragraph = "Tangled is the story of Rapunzel, a princess with long magical golden hair. She is taken away from her parents as a baby by Mother Gothel, who keeps her hidden in a tall tower to use the hair’s healing power. Rapunzel dreams of seeing the floating lanterns that appear every year on her birthday. One day, a thief named Flynn Rider enters her tower, and Rapunzel makes a deal with him to take her outside. During their journey, Rapunzel discovers the real world, finds courage, and learns the truth about who she is. In the end, she returns to her family and begins a new life filled with freedom and happiness."

story= paragraph.strip()

story = paragraph.split(".")

story= "\n-".join(story)

print("-" + story)
# Out:
# -Tangled is the story of Rapunzel, a princess with long magical golden hair
# - She is taken away from her parents as a baby by Mother Gothel, who keeps her hidden in a tall tower to use the hair’s healing power
# - Rapunzel dreams of seeing the floating lanterns that appear every year on her birthday
# - One day, a thief named Flynn Rider enters her tower, and Rapunzel makes a deal with him to take her outside
# - During their journey, Rapunzel discovers the real world, finds courage, and learns the truth about who she is
# - In the end, she returns to her family and begins a new life filled with freedom and happiness
# -

# %%
# 20. (Hard) Take a string. Use replace(), strip(), split(), and join() together to clean and reformat it as a proper sentence.

# %%
# Task
name=["Ishaan","Sunil","Rahee"]
name.append("Poonam")
name.append("Aditya")
name.extend(["Arpit","Pritam"])
name
# Out:
# ['Ishaan', 'Sunil', 'Rahee', 'Poonam', 'Aditya', 'Arpit', 'Pritam']

# %% [markdown]
# ## Here are 20 Practical Questions on Sets and If Statements
# Set Questions (1-10)

# %%
# 1. (Easy) Create a set with numbers {1, 2, 3, 2, 4, 1} and print it. What do you observe?
Set ={1, 2, 3, 2, 4, 1}
Set
print("Observed unique numbers:",Set)
# Out:
# Observed unique numbers: {1, 2, 3, 4}

# %%
#2. (Easy) Create an empty set using correct syntax and add 3 numbers using add().
name = set()
name
name.add(45)
name.add(55)
name.add(46)
name
# Out:
# {45, 46, 55}

# %%
# 3. (Easy) Given s = {10, 20, 30}, add multiple elements [40, 50, 60] using update().
s = {10, 20, 30}
s.update([40,50,60])
s
# Out:
# {10, 20, 30, 40, 50, 60}

# %%
# 4. (Medium) Remove element 20 from set s = {10, 20, 30, 40} using remove() and discard(). Show difference.
s = {10, 20, 30, 40}
s.remove(20)
s.discard(20)
s
# Out:
# {10, 30, 40}

# %%
#5. (Medium) Create two sets A = {1, 2, 3, 4} and B = {3, 4, 5, 6}. Print union, intersection, and difference.
A = {1, 2, 3, 4} 
B = {3, 4, 5, 6}
print("union:",A.union(B))
print("intersection:",A.intersection(B))
print("dofference:",A.difference(B))
# Out:
# union: {1, 2, 3, 4, 5, 6}
# intersection: {3, 4}
# dofference: {1, 2}

# %%
# 6. (Medium) Check if 25 is present in set s = {10, 20, 30, 40} using in keyword.
s = {10, 20, 30, 40}
print(25 in s)
# Out:
# False

# %%
# 7. (Hard) Create a set from the list [1, 2, 2, 3, 4, 4, 5] and print its length.
numbers = [1, 2, 2, 3, 4, 4, 5]
unique_numbers = set(numbers)
print(len(unique_numbers))
# Out:
# 5

# %%
#8. (Hard) Take 5 numbers as input from user, store them in a set, and print unique numbers only.
numbers = set()
for i in range(5):
    num = int(input("Enter a number: "))
    numbers.add(num)

print("Unique numbers are:", numbers)
# Out:
# Enter a number:  3
# Enter a number:  4
# Enter a number:  3
# Enter a number:  2
# Enter a number:  4
# Unique numbers are: {2, 3, 4}

# %%
#9. (Hard) Given two sets A = {1, 2, 3} and B = {3, 4, 5}, print elements that are in A but not in B.
A = {1, 2, 3}
B = {3, 4, 5}

result = A - B

print(result)
# Out:
# {1, 2}

# %%
#10. (Hard) Create a set and try to add a list [1,2,3] inside it. What happens?
my_set= set()
my_set.add([1,2,3])
print(my_set)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 3
#       1 #10. (Hard) Create a set and try to add a list [1,2,3] inside it. What happens?
#       2 my_set= set()
# ----> 3 my_set.add([1,2,3])
#       4 print(my_set)
#
# TypeError: unhashable type: 'list'

# %% [markdown]
# ### If Statement Questions (11-20)

# %%
#11. (Easy) Take age as input. If age >= 18, print "You are eligible to vote".
age = input("Age:")
if 'age >= 18':
   print("You are eligible to vote")
# Out:
# Age: 19
# You are eligible to vote

# %%
#12. (Easy) Take a number and check if it is positive, negative, or zero using if-elif-else.
number= input("Number:")

if 'number == +ve':
    print("positive")

elif 'number == -ve':
    print("negative")

else:
    print("zero")
# Out:
# Number: 12
# positive

# %%
#13. (Medium) Take two numbers and print the larger one using if-else.
number1 = 45
number2 = 84
if 'numbers1>numbers2':
        print("large number")
else:
    print("small number")
# Out:
# large number

# %%
#14. (Medium) Take a character and check if it is a vowel (a, e, i, o, u) using ifstatement.
char = input("Enter a character: ")

if char.lower() in "aeiou":
    print("Vowel")
else:
    print("Not a vowel")
# Out:
# Enter a character:  o
# Vowel

# %%
#15. (Medium) Take marks and print grade: ≥90 → A, ≥80 → B, ≥70 → C, else →Fail.
marks = int(input("Enter marks: "))

if marks >= 90:
    print("Grade A")
elif marks >= 80:
    print("Grade B")
elif marks >= 70:
    print("Grade C")
else:
    print("Fail")
# Out:
# Enter marks:  78
# Grade C

# %%
#16. (Hard) Take three numbers and print the largest one using if-elif-else.
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))

if a >= b and a >= c:
    print("Largest number is:", a)
elif b >= a and b >= c:
    print("Largest number is:", b)
else:
    print("Largest number is:", c)
# Out:
# Enter first number:  8
# Enter second number:  6
# Enter third number:  9
# Largest number is: 9

# %%
#17. (Hard) Take a number and check if it is even and greater than 50.
num = int(input("Enter a number: "))

if num % 2 == 0 and num > 50:
    print("Number is even and greater than 50")
else:
    print("Number is not even and greater than 50")
# Out:
# Enter a number:  47
# Number is not even and greater than 50

# %%
#18. (Hard) Take username and password. If username == "admin" and password =="1234", print "Login Successful", else "Login Failed".
username = input("Enter username: ")
password = input("Enter password: ")

if username == "admin" and password == "1234":
    print("Login Successful")
else:
    print("Login Failed")
# Out:
# Enter username:  admin
# Enter password:  1234
# Login Successful

# %%
#19. (Hard) Take a year as input and check if it is a leap year (divisible by 4 but not100, or divisible by 400).
year = int(input("Enter a year: "))

if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    print("Leap year")
else:
    print("Not a leap year")
# Out:
# Enter a year:  1985
# Not a leap year

# %%
#20. (Hard) Take three sides of a triangle and check if they can form a valid triangle(sum of any two sides > third side
a = int(input("Enter first side: "))
b = int(input("Enter second side: "))
c = int(input("Enter third side: "))

if a + b > c and a + c > b and b + c > a:
    print("Valid triangle")
else:
    print("Invalid triangle")
# Out:
# Enter first side:  5
# Enter second side:  5
# Enter third side:  6
# Valid triangle

# %%
#1. (Hard) Take three numbers as input from the user. Print the largest number andalso check whether all three numbers are equal or not.
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))

if a == b and b == c:
    print("All three numbers are equal")
    print("Largest number is:", a)
elif a >= b and a >= c:
    print("Largest number is:", a)
    print("All three numbers are not equal")
elif b >= a and b >= c:
    print("Largest number is:", b)
    print("All three numbers are not equal")
else:
    print("Largest number is:", c)
    print("All three numbers are not equal")
# Out:
# Enter first number:  67
# Enter second number:  45
# Enter third number:  89
# Largest number is: 89
# All three numbers are not equal

# %%
#2. (Hard) Take a year as input. Check if it is a leap year or not. (A year is leap if divisible by 4, but not by 100, unless also divisible by 400)
year = int(input("Enter a year: "))

if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    print("Leap year")
else:
    print("Not a leap year")
# Out:
# Enter a year:  2000
# Leap year

# %%
#3. (Hard) Take three sides of a triangle as input. Check if they can form a validtriangle (sum of any two sides must be greater than the third side). 
#If valid, also printthe type (Equilateral, Isosceles, or Scalene).
a = int(input("Enter first side: "))
b = int(input("Enter second side: "))
c = int(input("Enter third side: "))

if a + b > c and a + c > b and b + c > a:
    print("Valid triangle")

    if a == b and b == c:
        print("Equilateral triangle")
    elif a == b or b == c or a == c:
        print("Isosceles triangle")
    else:
        print("Scalene triangle")

else:
    print("Invalid triangle")
# Out:
# Enter first side:  7
# Enter second side:  7
# Enter third side:  8
# Valid triangle
# Isosceles triangle

# %%
#4. (Hard) Take a student's marks in 5 subjects. Calculate percentage and print grade
#according to these rules:
#• 90 or above → A+
#• 80–89 → A
#• 70–79 → B
#• 60–69 → C
#• Below 60 → Fail Also print "Passed with Distinction" if percentage >= 75.
sub1 = int(input("Enter marks of subject 1: "))
sub2 = int(input("Enter marks of subject 2: "))
sub3 = int(input("Enter marks of subject 3: "))
sub4 = int(input("Enter marks of subject 4: "))
sub5 = int(input("Enter marks of subject 5: "))

total = sub1 + sub2 + sub3 + sub4 + sub5
percentage = total / 5

print("Total marks:", total)
print("Percentage:", percentage)

if percentage >= 90:
    print("Grade: A+")
elif percentage >= 80:
    print("Grade: A")
elif percentage >= 70:
    print("Grade: B")
elif percentage >= 60:
    print("Grade: C")
else:
    print("Grade: Fail")

if percentage >= 75:
    print("Passed with Distinction")
# Out:
# Enter marks of subject 1:  89
# Enter marks of subject 2:  99
# Enter marks of subject 3:  68
# Enter marks of subject 4:  78
# Enter marks of subject 5:  58
# Total marks: 392
# Percentage: 78.4
# Grade: B
# Passed with Distinction

# %%
#5. (Hard) Take username, password, and age as input.
#• If username == "admin" and password == "python123" and age >= 18 → Print "Login Successful"
#• Else if age < 18 → Print "You are too young to login" Else → Print "Invalid Credentials"
username = input("Enter username: ")
password = input("Enter password: ")
age = int(input("Enter age: "))

if username == "admin" and password == "python123" and age >= 18:
    print("Login Successful")
elif age >= 18:
    print("You are too young to login")
else:
    print("Invalid Credentials")
# Out:
# Enter username:  admin
# Enter password:  python123
# Enter age:  19
# Login Successful

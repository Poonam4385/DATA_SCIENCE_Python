# %% [markdown]
# # 20 Practical Questions on Python Lists
#
# Easy Level (1-8)

# %%
# 1. Create a list named students with 5 student names and print it.
students = ["Ishaan","Rahee","Aditya","Arpit","Sunil"]
print(f"Students name:",students)
# Out:
# Students name: ['Ishaan', 'Rahee', 'Aditya', 'Arpit', 'Sunil']

# %%
# 2. Create a list numbers = [10, 20, 30, 40, 50] and print its type and length using len().
numbers=[10,20,30,40,50,]
print(f"Numbers: ",numbers,"Type: ",type(numbers),"Length: ",len(numbers))
# Out:
# Numbers:  [10, 20, 30, 40, 50] Type:  <class 'list'> Length:  5

# %%
# 3. Create an empty list and append 3 numbers into it using append().
lists = []
lists.append(20)
lists.append(40)
lists.append(60)
lists
# Out:
# [20, 40, 60]

# %%
# 4. Given lst = [1, 2, 3], use extend() to add [4, 5, 6] to it.
lst = [1,2,3]
lst.extend([4,5,6])
lst
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
# 5. Use insert() to add number 100 at index 2 in the list [10, 20, 30, 40].
lists = [10,20,30,40]
lists.insert(2,100)
lists
# Out:
# [10, 20, 100, 30, 40]

# %%
# 6. Remove the element 50 from the list [10, 20, 50, 30, 50] using remove().
lists = [10, 20, 50, 30, 50]
lists.remove(50)
lists
# Out:
# [10, 20, 30, 50]

# %%
# 7. Use pop() to remove the last element from lst = [5, 10, 15, 20] and print the list.
lst = [5, 10, 15, 20] 
lst.pop(3)
lst
# Out:
# [5, 10, 15]

# %%
# 8. Clear all elements from the list data = [1, 2, 3, 4, 5] using clear().
data = [1, 2, 3, 4, 5] 
data.clear()
data
# Out:
# []

# %% [markdown]
#  ##### Medium Level (9-15)

# %%
#9. Find the index of 25 in the list [10, 15, 25, 30, 40] using index().
number = [10, 15, 25, 30, 40] 
number.index(25)
# Out:
# 2

# %%
#10. Count how many times 7 appears in the list [7, 2, 7, 5, 7, 8] usingcount().
lists= [7, 2, 7, 5, 7, 8]
lists.count(7)
# Out:
# 3

# %%
# 11. Sort the list [45, 12, 78, 23, 56] in ascending order using sort().
lists= [45, 12, 78, 23, 56] 
lists.sort()
lists
# Out:
# [12, 23, 45, 56, 78]

# %%
# 12. Sort the list [45, 12, 78, 23, 56] in descending order.
lists = [45, 12, 78, 23, 56] 
lists.sort(reverse=True)
lists
# Out:
# [78, 56, 45, 23, 12]

# %%
# 13. Reverse the list fruits = ["apple", "banana", "mango", "orange"] using reverse().
fruits = ["apple", "banana", "mango", "orange"]
fruits.sort(reverse=True)
fruits
# Out:
# ['orange', 'mango', 'banana', 'apple']

# %%
# 14. Create a copy of list original = [1, 2, 3, 4] using copy() and print both.
original1= [1, 2, 3, 4]
original2=original1.copy()
print(original1 + original2)
# Out:
# [1, 2, 3, 4, 1, 2, 3, 4]

# %%
# 15. Take a sentence from user (e.g. "I love Python programming") and convert it into a list of words using split().
sentence = input("Sentence:")
words = sentence.split()
print(words)
# Out:
# Sentence: I love Python programming
# ['I', 'love', 'Python', 'programming']

# %% [markdown]
# ##### Hard / Mixed Level (16-20)

# %%
# 16. Create a list of 5 numbers. Append 3 more numbers, then sort it in descending order.
numbers = [44,55,66,33,22]
numbers.append(77)
numbers.append(88)
numbers.append(99)
numbers.sort(reverse=True)
numbers
# Out:
# [99, 88, 77, 66, 55, 44, 33, 22]

# %%
# 17. Create a list. Insert "Python" at index 0, then remove the last element using pop(), and print the length.
languages = ["jawa","c++","oracal","R","jawaskript"]
languages.insert(0,"Python")
languages.pop(5)
print(len(languages))
# Out:
# 5

# %%
# 18. Take 5 city names as input from user and store them in a list. Then print them in reverse order.
cities = []

for i in range(5):
    city = input("Enter city name: ")
    cities.append(city)
print("Cities in reverse sorted order:",cities.sort(reverse=True))
print(cities)
# Out:
# Enter city name:  Pune
# Enter city name:  Sangali
# Enter city name:  Satara
# Enter city name:  Solapur
# Enter city name:  Nashi
# Cities in reverse sorted order: None
# ['Solapur', 'Satara', 'Sangali', 'Pune', 'Nashi']

# %%
# 19. Given data = [10, 20, 30, 20, 40, 20], remove all occurrences of 20 (use loop or multiple remove).
data = [10, 20, 30, 20, 40, 20]
while 20 in data:
    data.remove(20)
print(data)
# Out:
# [10, 30, 40]

# %%
# 20. Create a list of student marks. Sort it, find the highest and lowest mark using list methods, and print them.
students_marks=[59.89,76,45,73,87,69]
students_marks.sort(reverse=True)
print("highest marks:",students_marks[0],"lowvest marks:",students_marks[5])
# Out:
# highest marks: 87 lowvest marks: 45

# %%
key=["a","b","c"]
dict1 =dict.fromkeys(key,20)
dict1
# Out:
# {'a': 20, 'b': 20, 'c': 20}

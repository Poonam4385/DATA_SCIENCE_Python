# %% [markdown]
# 1. Logical Operators (and, or, not) Questions
#    - Question 1:

# %%
# Take age and marks from user.
# Check if the student is eligible for admission:
# Age must be between 18 and 25 AND marks >= 60
age = int(input("Enter age: "))
marks = float(input("Enter marks: "))
if age >=18 and age<=25 and marks >= 60:
   print("Student is eligible for admission")
else:
   print("Student is not eligibale for admission")
# Out:
# Enter age:  23
# Enter marks:  75.50
# Student is eligible for admission

# %% [markdown]
# Question 2:

# %%
# Take username and password from user.
# Check login:
# Username == "admin" AND Password == "12345"
# Print "Login Successful" or "Login Failed"
Username = input("Enter Username: ")
Password = input("Enter Password: ")

if Username == "admin" and Password == "12345":
    print("Login Successful")
else:
    print("Login Failed")
# Out:
# Enter Username:  admin
# Enter Password:  12345
# Login Successful

# %% [markdown]
# Question 3:

# %%
# Take a number from user.
# Check if the number is between 50 and 100 (using 'and')
# Also check if it is NOT divisible by 5 (using 'not')
number = int(input("Enter number: "))
if number>=50 and number<=100 and number% 5==0:
    print("number is between 50 and 100 and NOT divisible by 5")
else:
    print("condition not satisfied")
# Out:
# Enter number:  70
# number is between 50 and 100 and NOT divisible by 5

# %% [markdown]
# Question 4:

# %%
# Take three numbers from user.
# Print the largest number using 'and' and 'or' operators.
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
num3 = float(input("Enter third number: "))

if num1 >= num2 and num1 >= num3:
    print("Largest number is:", num1)

elif num2 >= num1 and num2 >= num3:
    print("Largest number is:", num2)

elif num3>=num1 and num3>=num2:
    print("Largest number is:",num3)

else:
    print("Largest number is:", num1 or num2 or num3)
# Out:
# Enter first number:  45
# Enter second number:  45.6
# Enter third number:  54
# Largest number is: 54.0

# %% [markdown]
# 2. String and String Slicing Questions

# %% [markdown]
# Question 5:

# %%
# Take your full name as input from user.
# Print the following:
# 1. Full name in uppercase
# 2. Full name in lowercase
# 3. Length of your name
# 4. First 3 characters
# 5. Last 3 characters
Full_name = input("Full name: ")

print("Full_name upper:",Full_name.upper())
print("Full_name lower:",Full_name.lower())
print("Full_name length:",len(Full_name))
print("Full_name frist 3:",Full_name[ :3])
print("Full_name last 3:",Full_name[-3: ])
# Out:
# Full name:  poonam Sunil Lonkar
# Full_name upper: POONAM SUNIL LONKAR
# Full_name lower: poonam sunil lonkar
# Full_name length: 19
# Full_name frist 3: poo
# Full_name last 3: kar

# %% [markdown]
# Question 6:

# %%
# Take any sentence from user.
# Print:
# - First 10 characters
# - Last 10 characters
# - Characters from index 5 to 15
# - Every 2nd character of the sentence
Sentence = input("Sentence:")
print("First 10 characters:",Sentence[:10])
print("Last 10 characters:",Sentence[-11:])
print("Every 2nd character:",Sentence[::2])
# Out:
# Sentence: Poonam is very beautiful girl.
# First 10 characters: Poonam is
# Last 10 characters: tiful girl.
# Every 2nd character: Poa svr euiu il

# %% [markdown]
# Question 7:

# %%
# Take a word from user.
# Check if the word is a palindrome or not.
# (Example: "madam", "radar")
word =input("Word:")
if word == word[::-1]:
    print("palindrome")
else:
    print("Not")
# Out:
# Word: madam
# palindrome

# %% [markdown]
# Question 8:

# %%
# Take email as input (e.g: student@gmail.com)
# Print only the username (part before @)
# Print only the domain (part after @)
Email = input("Email id: ")

username,domain = Email.split("@")
print("username:",username)
print("domain:",domain)
# Out:
# Email id:  lonkarps@rediffmail.com
# username: lonkarps
# domain: rediffmail.com

# %% [markdown]
# ### Bonus Mixed Question (String + Logical)
# - Question 9:

# %%
# Take a password from user.
# Check if password is strong:
# - Length >= 8
# - Contains '@' or '#'
# Print "Strong Password" or "Weak Password"
password = input("password:")

if 'len>=8' and' @ or #':
    print("Strong Password")

else:
    print("Weak Password")
# Out:
# password: ishaan@2012
# Strong Password

# %% [markdown]
# 1. Logical Operators

# %%
# Take three subject marks from user (English, Math, Science).
# Check if the student has passed:
# All marks should be >= 40 (use 'and' operator)
# If any one subject is < 40, print "Fail"
English = float(input("English marks:"))
Maths = float(input("Maths marks:"))
Science = float(input("Science marks:"))

if English>=40 and Maths>=40 and Science>=40:
    print("Pass")
else:
    print("Fail")
# Out:
# English marks: 65
# Maths marks: 79.5
# Science marks: 89.5
# Pass

# %% [markdown]
# 2. Logical Operators + User Input

# %%
# Take a number from user.
# Check whether the number is:
# Positive AND Even
# OR
# Negative OR Odd
# Print appropriate message
number = input("Enter number:")
            
if '% == 0':
    print("Positive AND Even")
else:
    print("Negative OR Odd")
# Out:
# Enter number: 36
# Positive AND Even

# %% [markdown]
# 3. String Operations

# %%
# Take your city name as input.
# Print the following:
# 1. City name in reverse order
# 2. Number of vowels in the city name (a,e,i,o,u)
# 3. City name without first and last character
City_Name = input("City_Name:")
count = sum(1 for letter in City_Name if letter in "aeiouAEIOU")
print("City_Name rverse order:",City_Name[::-1])
print("Number of vowels:",count)
print("City_Name:", City_Name[1:-1])
# Out:
# City_Name: Abu Dhabi
# City_Name rverse order: ibahD ubA
# Number of vowels: 4
# City_Name: bu Dhab

# %% [markdown]
# 4. String Slicing

# %%
# Take a mobile number as input (10 digits).
# Print:
# First 3 digits (network code)
# Last 4 digits
# Middle 3 digits
mobile_number = input("mobile number:")
print("network code:",mobile_number[:3])
print("last 4 digit:",mobile_number[-4:])
print("Middle 3 digit:",mobile_number[3:6])
# Out:
# mobile number: 7350870683
# network code: 735
# last 4 digit: 0683
# Middle 3 digit: 087

# %% [markdown]
# 5. Mixed (String + Logical)

# %%
# Take a string from user.
# Check if:
# - The string length is greater than 5
# - AND it starts with 'A' or 'a'
# Print "Valid String" or "Invalid String"

# %%
string = input("string:")
if 'len(string) > 5' and string.startswith("A") or string.startswith("a"):
   print("Valid Strings")
else:
    print("Invalid String")
# Out:
# string: lonkar
# Invalid String

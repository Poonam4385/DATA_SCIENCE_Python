# %% [markdown]
# ## 20 Questions on if, if-else, and if-elif-else Statements
# Easy Level (1-7)

# %%
#1. Write a program to check if a number is positive or negative.
num= int(input("Enter number:"))
if num > 0:
    print("Number is positive")
else:
    print("Number is negative")
# Out:
# Enter number: -9
# Number is negative

# %%
#2. Take age as input. If age is greater than or equal to 18, print "You can vote".
age = int(input("Enter age:"))
if age >= 18:
    print("You can vote:",age)
else:
    print("You can not vote:",age)
# Out:
# Enter age: 38
# You can vote: 38

# %%
#3. Take two numbers and print the larger one using if-else.
A = 30
B = 89
if A>B:
    print("larger:",A)
else:
    print("larger:",B)
# Out:
# larger: 89

# %%
#4. Check if a given number is even or odd.
value = int(input("Enter value:"))
    
if value % 2 == 0:
        print(f"Even value:{value}")
            
else:
        print(f"odd value:{value}")
# Out:
# Enter value: 46
# Even value:46

# %%
#5. Take a character and check if it is 'A' or not.

char = input("Enter a character: ")

if char == "A":
    print("It is A")
else:
    print("It is not A")
# Out:
# Enter a character:  u
# It is not A

# %%
#6. Take marks and print "Pass" if marks >= 40, otherwise "Fail".
marks = int(input("ENTER Marks:"))

if marks >= 40:
    print(f"Pass:{marks}")
else:
    print(f"fail:{marks}")
# Out:
# ENTER Marks: 38
# fail:38

# %%
#7. Check if a number is divisible by 5
num = int(input("Enter a number: "))

if num % 5 == 0:
    print("Divisible by 5")
else:
    print("Not divisible by 5")
# Out:
# Enter a number:  35
# Divisible by 5

# %% [markdown]
# Medium Level (8-14)

# %%
#8. Take a number and print whether it is positive, negative, or zero.
num = int(input("Enter a number: "))

if num > 0:
    print("Positive")
elif num < 0:
    print("Negative")
else:
    print("Zero")
# Out:
# Enter a number:  45
# Positive

# %%
#9. Take three numbers and print the largest number using if-elif-else.
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))

if a >= b and a >= c:
    print("Largest number is:", a)
elif b >= a and b >= c:
    print("Largest number is:", b)
else:
    print("Largest number is:", c)
# Out:
# Enter first number:  45
# Enter second number:  76
# Enter third number:  82
# Largest number is: 82

# %%
#10. Take a year and check if it is a leap year (div by 4 but not 100, or div by 400).
year = int(input("Enter year: "))

if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    print("Leap year")
else:
    print("Not a leap year")
# Out:
# Enter year:  1985
# Not a leap year

# %%
#11. Take a character and check if it is a vowel (a, e, i, o, u) or consonant.
char = input("Enter a character: ")

if char.lower() in "aeiou":
    print("Vowel")
else:
    print("Consonant")
# Out:
# Enter a character:  b
# Consonant

# %%
#12. Take salary as input. If salary > 50000 print "High", elif salary > 30000 print "Medium", else print "Low".
salary = int(input("Enter salary: "))

if salary > 50000:
    print("High")
elif salary > 30000:
    print("Medium")
else:
    print("Low")
# Out:
# Enter salary:  40000
# Medium

# %%
#13. Take temperature in Celsius. If > 30 print "Hot", 20-30 print "Warm",< 20 print "Cold"
temp = int(input("Enter temperature in Celsius: "))

if temp > 30:
    print("Hot")
elif temp >= 20 and temp <= 30:
    print("Warm")
else:
    print("Cold")
# Out:
# Enter temperature in Celsius:  24
# Warm

# %%
#14. Take username and password. If both correct print "Login Successful", else print "Login Failed".
username = input("Enter username: ")
password = input("Enter password: ")

if username == "admin" and password == "1234":
    print("Login Successful")
else:
    print("Login Failed")
# Out:
# Enter username:  admin
# Enter password:  1234
# Login Successful

# %% [markdown]
# ## Hard Level (15-20)

# %%
# 15. Take three sides of a triangle. Check if they form a valid triangle.
#Ifyes, also print if it is Equilateral, Isosceles, or Scalene.
a = int(input("Enter first side: "))
b = int(input("Enter second side: "))
c = int(input("Enter third side: "))

if a + b > c and a + c > b and b + c > a:
    print("Valid triangle")

    if a == b and b == c:
        print("Equilateral triangle")
    elif a == b or b == c or a == c:
        print("Isosceles triangle")
    else:
        print("Scalene triangle")
else:
    print("Invalid triangle")
# Out:
# Enter first side:  8
# Enter second side:  8
# Enter third side:  9
# Valid triangle
# Isosceles triangle

# %%
#16. Take student marks in 5 subjects. Calculate percentage and give
#grade: 90+ → A+, 80-89 → A, 70-79 → B, 60-69 → C, below 60 → Fail.
m1 = int(input("Enter subject 1 marks: "))
m2 = int(input("Enter subject 2 marks: "))
m3 = int(input("Enter subject 3 marks: "))
m4 = int(input("Enter subject 4 marks: "))
m5 = int(input("Enter subject 5 marks: "))

total = m1 + m2 + m3 + m4 + m5
percentage = total / 5

print("Total marks:", total)
print("Percentage:", percentage)

if percentage >= 90:
    print("Grade: A+")
elif percentage >= 80:
    print("Grade: A")
elif percentage >= 70:
    print("Grade: B")
elif percentage >= 60:
    print("Grade: C")
else:
    print("Grade: Fail")
# Out:
# Enter subject 1 marks:  78
# Enter subject 2 marks:  98
# Enter subject 3 marks:  67
# Enter subject 4 marks:  87
# Enter subject 5 marks:  54
# Total marks: 384
# Percentage: 76.8
# Grade: B

# %%
#17. Take a number. Check if it is divisible by both 3 and 5. If yes print
#"FizzBuzz", by 3 print "Fizz", by 5 print "Buzz", else print the number.
num = int(input("Enter a number: "))

if num % 3 == 0 and num % 5 == 0:
    print("FizzBuzz")
elif num % 3 == 0:
    print("Fizz")
elif num % 5 == 0:
    print("Buzz")
else:
    print(num)
# Out:
# Enter a number:  9
# Fizz

# %%
#18. Take age and gender. If age >= 18 and gender is "Male" print
#"Eligible for Army", elif age >= 18 and gender "Female" print "Eligible for
#Other Services", else print "Not Eligible".
age = int(input("Enter age: "))
gender = input("Enter gender: ")

if age >= 18 and gender == "Male":
    print("Eligible for Army")
elif age >= 18 and gender == "Female":
    print("Eligible for Other Services")
else:
    print("Not Eligible")
# Out:
# Enter age:  42
# Enter gender:  female
# Not Eligible

# %%
#19. Take a character. Check if it is uppercase, lowercase, digit, or special character.
char = input("Enter a character: ")

if char >= "A" and char <= "Z":
    print("Uppercase")
elif char >= "a" and char <= "z":
    print("Lowercase")
elif char >= "0" and char <= "9":
    print("Digit")
else:
    print("Special character")
# Out:
# Enter a character:  h
# Lowercase

# %%
#20. Take three numbers. Print them in ascending order using if-elif-else (without using sort()).
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))

if a <= b and a <= c:
    if b <= c:
        print(a, b, c)
    else:
        print(a, c, b)

elif b <= a and b <= c:
    if a <= c:
        print(b, a, c)
    else:
        print(b, c, a)

else:
    if a <= b:
        print(c, a, b)
    else:
        print(c, b, a)
# Out:
# Enter first number:  5
# Enter second number:  7
# Enter third number:  8
# 5 7 8

# %%
name = "Ishaan"
password = "2012"

user_id = input("name:")
if user_id == name:
     user_password=input("passwrod:")
     if user_password==password:
        print("login ok")
     else:
          print("invalid password")
else:
    print("invalid user_id")
# Out:
# name: Ishaan
# passwrod: 2012
# login ok

# %%
Annual_income = 1000000
CIBIL_Score =750

userA_income=int(input("User annual income:"))

if userA_income >= Annual_income:
    
    userCIBIL_Score=int(input("user CIBIL Score:"))
    
    if userCIBIL_Score >= CIBIL_Score:
        print("lone approve")
    else:
        print("userCIBIL_Score require more than 750")
else:
    print(f"loan is reject bcz your annual income {userA_income} less than {Annual_income}")
# Out:
# User annual income: 1200000
# user CIBIL Score: 750
# lone approve

# %%
number = 1

while number <= 10:
    if number > 0:
        print(number, "positive")
    else:
        print(number, "negative")

    number = number + 1
# Out:
# 1 positive
# 2 positive
# 3 positive
# 4 positive
# 5 positive
# 6 positive
# 7 positive
# 8 positive
# 9 positive
# 10 positive

# %%
num = 12345
reverse = 0

while num > 0:
    digit = num % 10
    reverse = reverse * 10 + digit
    num = num // 10

print(reverse)
# Out:
# 54321

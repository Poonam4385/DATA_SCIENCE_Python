# %% [markdown]
# ### Easy Level Practicals (Basic Concepts)
# 1. Comments & Print
# # Python

# %%
A = input("Name: ") # Name of the student
B = input("college and classes: ") # Name of the college # Name of the classes 
C = input("Course: ") # """Name of the course"""
# Out:
# Name:  Poonam Sunil Lonkar
# college and classes:  IGNOU and Naresh IT
# Course:  Full Stack Data Science and Gen AI with Agentic AI

# %% [markdown]
# 2. Indentation Practice

# %%
# Correct the indentation in the following code:
if True:
    print("Hello World")
print("Welcome to Python")
# Out:
# Hello World
# Welcome to Python

# %% [markdown]
# 3. Variables Declaration

# %%
# Create variables for: 
# name (string), age (integer), height (float), is_student (boolean) # Print all variables with their data types using type() 
Name = "Poonam Sunil Lonkar"
Age = 42
Height = 5.5
Student = True
print(Name,type(Name))
print(Age,type(Age))
print(Height,type(Height))
print(Student,type(Student))
# Out:
# Poonam Sunil Lonkar <class 'str'>
# 42 <class 'int'>
# 5.5 <class 'float'>
# True <class 'bool'>

# %% [markdown]
# 4. Variable Naming Rules

# %%
# Which of these are valid variable names? Fix the invalid ones: # 1st_name, my name, total@amount, class, MyVar, _score, 99marks
print("Poonam Sunil Lonkar")
print("30,000/-")
# Out:
# Poonam Sunil Lonkar
# 30,000/-

# %% [markdown]
# ### Sumit Sir Notes
# 5. Arithmetic Operators

# %%
# Take two numbers from user and print: 
# Sum, Difference, Product, Division, Floor Division, Modulus, Power 
A = 40
B = 20
print("Sum:",A + B)
print("Difference:",A - B)
print("Product:",A * B)
print("Division:",A / B)
print("Floor Division:",A // B)
print("Module:",A % B)
print("Power:",A ** B)
# Out:
# Sum: 60
# Difference: 20
# Product: 800
# Division: 2.0
# Floor Division: 2
# Module: 0
# Power: 109951162777600000000000000000000

# %% [markdown]
# 6. Comparison Operators

# %%
# Equal, Not Equal, Greater, Smaller, Greater or Equal, Smaller or Equal
A = 40
B = 30
print("Equal:", A == B)
print("Not equal:", A != B)
print("Greater:", A > B)
print("Smaller:", A < B)
print("Greater or equal:", A >= B)
print("Smaller or equal:", A <= B)
# Out:
# Equal: False
# Not equal: True
# Greater: True
# Smaller: False
# Greater or equal: True
# Smaller or equal: False

# %% [markdown]
# 7. Assignment Operators

# %%
# Initialize a = 10 
# Use all assignment operators (+=, -=, *=, /=, //=, %=, **=) and print after each 
a = 10
a += 10
print(a)

a -= 10
print(a)

a *= 10
print(a)

a /=10
print(a)

a //= 10
print (a)

a %= 10
print(a)

a **= 10
print(a)
# Out:
# 20
# 10
# 100
# 10.0
# 1.0
# 1.0
# 1.0

# %% [markdown]
# 8. Local vs Global Variable

# %%
# Create a global variable 'college' 
# Inside a function, try to print it (use global keyword if needed) 
# Demonstrate local variable inside function 
College = "IGNOU"
print("Name of College: ",College)
# Out:
# Name of College:  IGNOU

# %% [markdown]
# ### Medium Level Practicals
# 9. Simple Calculator

# %%
# Create a simple calculator that takes two numbers and one operator (+,-,*,/,//,%,**)  # from the user and shows the result. 
num1 = float(input("Enter frist num:"))
num2 = float(input("Enter second num:"))
operator = input("Enter operator (+,-,*,/,//,%,**):")

if operator =="+":
    result = num1 + num2

elif operator == "-":
    result = num1-num2

elif operator =="*":
    result = num1 * num2

elif operator =="/":
    if num2 !=0:
        result = num1/num2
    else:
        result="cannot divide by zero"

elif operator =="//":
    if num2 !=0:
        result = num1//num2
    else:
        result="cannot divide by zero"

elif operator == "%":
    if num2 !=0:
        result = num1 % num2
    else:
         result="cannot divide by zero"

elif operator =="**":
    result = num1 ** num2
else:
    result= "invalid operator"

print("Result:",result)
# Out:
# Enter frist num: 30056295
# Enter second num: 2.7
# Enter operator (+,-,*,/,//,%,**): /
# Result: 11131961.11111111

# %% [markdown]
# 10. Temperature Converter

# %%
# Convert temperature from Celsius to Fahrenheit and vice versa. # Formula: F = (C * 9/5) + 32 

choice=input("c to f (c) or f to c(f)")

if choice =="c":
    c=float(input("enter celsisu:"))
    print("fahenheit =",(c*9/5) +32)

elif choice =="f":
    
    f=float(input("enter fahrehgeit:"))
    print("celsius",(f-32)*5/9)
else:
    print("invalid choice")
# Out:
# c to f (c) or f to c(f) c
# enter celsisu: 45
# fahenheit = 113.0

# %% [markdown]
# 11. Area and Perimeter Calculator

# %%
# Take radius of circle from user and calculate: 
# Area and Circumference of circle 
# (Use pi = 3.14) 
pi = 3.14
radius=float(input("radius of circle:"))
             
area = pi * radius * radius
circumference = 2 * pi * radius

print("Area of circle:", area)
print("Circumference of circle:", circumference)
# Out:
# radius of circle: 4
# Area of circle: 50.24
# Circumference of circle: 25.12

# %% [markdown]
# 12. Student Grade Calculator

# %%
# Take marks of 5 subjects. 
# Calculate percentage and print grade: 
# >=90 → A+, >=80 → A, >=70 → B, >=60 → C, else → Fail 
Physics = 80
Chemistry = 75
Maths = 90
Biology = 85
English = 67
Total_marks = Physics+Chemistry+Maths+Biology+English
print("Total_ marks:",total_marks)
Percentage = (total_marks/500)*100
print("Percentage:",Percentage)
if Percentage >= 90:
    grade = "A+"
elif Percentage >= 80:
    grade = "A"
elif Percentage >= 70:
    grade = "B"
elif Percentage >= 60:
    grade = "C"
else:
    grade = "Fail"

print("Grade:", grade)
# Out:
# Total_ marks: 397
# Percentage: 79.4
# Grade: B

# %% [markdown]
# 13. Swap Two Variables

# %%
# Take two numbers from user and swap them using: # a) Third variable 
# b) Without third variable (Python way) 
# Take two numbers from user

a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

print("Before swapping:")
print("a =", a)
print("b =", b)

# a) Swap using third variable
temp = a
a = b
b = temp

print("After swapping using third variable:")
print("a =", a)
print("b =", b)
# Out:
# Enter first number:  45
# Enter second number:  54
# Before swapping:
# a = 45
# b = 54
# After swapping using third variable:
# a = 54
# b = 45

# %% [markdown]
# 14. Logical Operators Practice

# %%
# Take age and salary. 
# Check if person is eligible for loan: 
# Age between 18-60 AND salary > 25000
age = input("Age:")
salary = input("Salary:")
if 'age >=18 or >=60' and 'salary >=25000':
    print("person is eligible for loan")
else:
    print("person is not eligible for loan")
# Out:
# Age: 29
# Salary: 20000
# person is eligible for loan

# %% [markdown]
# 15. Dynamic Typing Demo

# %%
# Create a variable x = 10 
# Then change it to string, then float, then boolean # Print type after each change
x = 10
print("Type:",x,type(x))
x = str(x)
print("string:",x,type(x))
x=float(x)
print("float:",x,type(x))
x= bool(x)
print("boolean:",x,type(x))
# Out:
# Type: 10 <class 'int'>
# string: 10 <class 'str'>
# float: 10.0 <class 'float'>
# boolean: True <class 'bool'>
